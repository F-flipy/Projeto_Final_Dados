# %% [markdown]
# <a href="https://colab.research.google.com/github/F-flipy/Projeto_Final_Dados/blob/main/ETL_DF_Matriculas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Escola: SoulCode Academy
#
# Curso: Bootcamp Analista de Dados - Martech - AD2
#
# Tema: Educação
#
# Professores: Franciane Rodrigues e Douglas Ribeiro
#
# Monitor: Jonathas Carneiro
#
# Orientadora: Franciane Rodrigues
#
# Alunas(os):
#
# - Camila Duarte
# - Dener Ramos
# - Francielle Felipe
# - Gessyca Oliveira
# - Gustavo Victor
# - Israel Cordeiro.

# %% [markdown]
# **PERGUNTA DE NEGÓCIO:** Como está o ensino da educação básica no Brasil antes e pós-pandemia?
#
# Aplicação dos 5w's
# * Who (quem): Educação no Brasil
# * What (o que): Ensino Básico (Ensino fundamental e Médio)
# * Why (por que): Verificar o impacto da pandemia de Covid19 na educação no país
# * When (quando): Anos de 2018, 2020 e 2022
# * Where (onde): Brasil e suas regiões

# %% [markdown]
# ## **Informações sobre os dados**
# Este conjunto de dados fornece uma visão abrangente das matrículas escolares dos anos de 2018, 2020 e 2022.
#
# Fontes: https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/sinopses-estatisticas/educacao-basica

# %% [markdown]
# # **Dicionário de Dados**

# %% [markdown]
# ## Nome original - nome atualizado: descrição
#
# ## DF Idades
#
# - Ano - ano: Ano de realização do censo;
# - Unidade Geográfica - unid_geográfica: Região e Estados com dados do censo;
# - 6_10_anos : Soma dos alunos matriculados de 6 a 10 anos;
# - 11_14_anos : Soma dos alunos matriculados de 11 a 14 anos;
# - 15_17_anos : Soma dos alunos matriculados de 15 a 17 anos;
#
# ## DF  Sexo e Cor
# - Ano - ano: Ano de realização do censo;
# - und_geografica: Região e Estados com dados do censo;
# - total_fem : total femininos
# - nao_dec_fem : Não declarado feminino
# - branca_fem : mulheres brancas
# - preta_fem : mulheres pretas
# - parda_fem : mulheres pardas
# - amarela_fem	: mulheres amarelas
# - indígena_fem : mulheres indigenas
# - total_masc : total masculino
# - nao_dec_masc : Não declarado masculino
# - branca_masc : homens brancos
# - preta_masc : homens pretos
# - parda_masc	: homens pardos
# - amarela_masc : homens amarelos
# - indígena_masc : homens indigenas
#
#
#
# ## DF Taxa de rendimento
#
# - Ano - ano: Ano de realização do censo;
# - Unidade Geográfica - unid_geográfica: Região e Estados com dados do censo;
# - Localização - localizacao : Matriculas realizadas de acordo com a localização zona rural ou urbana;
# - Dependencia Administrativa - dependencia_adm : Matrículas realizadas de acordo com o tipo de escola Estadual, Municipal,
# - Pública, Federal ou Privada;
# - Total - total_fund_aprov : Número total de alunos aprovados no Ensino Fundamental;
# - Anos Iniciais - anos_finais_fund_aprov : Número total de alunos aprovados nos Anos Iniciais do Ensino Fundamental, inclui turmas do 1º ao 5º ano;
# - Anos Finais - anos_iniciais_fund_aprov : Número total de alunos aprovados nos Anos Iniciais do Ensino Fundamental, inclui turmas do 6º ao 9º ano;
# - total_medio_aprov : Número total de alunos aprovados no Ensino Médio;
# - total_fund_reprov : Número total de alunos reprovados no Ensino Fundamental;
# - anos_finais_fund_reprov : Número total de alunos reprovados nos Anos Iniciais do Ensino Fundamental, inclui turmas do 1º ao 5º ano;
# - anos_iniciais_fund_reprov : Número total de alunos reprovados nos Anos Iniciais do Ensino Fundamental, inclui turmas do 6º ao 9º ano;
# - total_medio_reprov : Número total de alunos reprovados no Ensino Médio;
# - total_fund_aband : Número total de alunos que abandonaram o Ensino Fundamental;
# - anos_finais_fund_aband : Número total de alunos que abandonaram o Ensino Fundamental, nos Anos Iniciais, inclui turmas do 1º ao 5º ano;
# - anos_iniciais_fund_aband : Número total de alunos que abandonaram o Ensino Fundamental, nos Anos Iniciais, inclui turmas do 6º ao 9º ano;
# - total_medio_aband : Número total de alunos que abandonaram o Ensino Médio.
#
# ## DF Matriculas
#
# - ano: Ano de realização do censo;
# - unid_geográfica: Região e Estados com dados do censo;
# total_fund : Soma total das matrículas do Ensino Fundamental, inclui turmas do 1º ao 9º ano;
# - anos_iniciais : Soma dos Anos Iniciais do Ensino Fundamental, inclui matrículas em turmas do 1º ao 5º ano;
# - anos_finais : Soma dos Anos Iniciais do Ensino Fundamental inclui matrículas em turmas do 6º ao 9º ano;
# - total_medio : Soma total do Ensino Médio inclui matrículas do Ensino Médio - Propedêutico, Curso Técnico Integrado (Ensino Médio Integrado) e Ensino Médio Normal/Magistério;
# - total_geral : Soma total das matrículas realizadas em cada período (ano) de censo e região geográfica

# %% [markdown]
# ## Instalações e Importações

# %%
# Instalação de pacotes
# !pip install gcsfs
# !pip install pandera

# %%
# Abertura de bibliotecas
import os
import pandas as pd
import numpy as np
import pandera as pa
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from google.cloud import storage

# %% [markdown]
# # **Extração**

# %% [markdown]
# ## Google Drive

# %%
# Conexão com para Google Drive
'''
from google.colab import drive
drive.mount('/content/drive')
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/drive')\n"

# %%
# Extração por Google Drive
'''
df_s = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_sexo_cor.csv', sep=',', encoding='utf-8')
df_t = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_tipo_escola.csv', sep=',', encoding='utf-8')
df_m = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_matricula.csv', sep=',', encoding='utf-8')
df_i = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_idade.csv', sep=',', encoding='utf-8')
'''
# Out:
# "\ndf_s = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_sexo_cor.csv', sep=',', encoding='utf-8')\ndf_t = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_tipo_escola.csv', sep=',', encoding='utf-8')\ndf_m = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_matricula.csv', sep=',', encoding='utf-8')\ndf_i = pd.read_csv('/content/drive/MyDrive/Projeto_final/bruto/projeto_educacao_bruto_idade.csv', sep=',', encoding='utf-8')\n"

# %% [markdown]
# ## **Google Cloud Platform**

# %%
#  CONFIGURANDO DA CHAVE DE SEGURANCA - ACESSO O PROJETO
serviceAccount = '/content/projeto-final-educacao-4a6af66d56a4.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# %%
# Configurações Google Cloud Storage
client = storage.Client()
bucket = client.get_bucket('educacao13')
bucket.blob('blob_name')
path_m = 'gs://educacao13/projeto_educacao/bruto/Matriculas.csv'
path_i = 'gs://educacao13/projeto_educacao/bruto/Idade.csv'
path_s = 'gs://educacao13/projeto_educacao/bruto/Sexo_Cor.csv'
path_t = 'gs://educacao13/projeto_educacao/bruto/Tipo_Escola.csv'

# %%
# Leitura das tabelas (matrículas, idade, sexo_cor e tipo_escola)
df_m = pd.read_csv(path_m)
df_i = pd.read_csv(path_i)
df_s = pd.read_csv(path_s)
df_t = pd.read_csv(path_t)

# %% [markdown]
# ## **Concatenando**
#
# ####Concatenando os dataframes acima para criar um único dataframe

# %%
# Selecção de apenas algumas colunas para adicionar no DF
df_1 = df_m[['Total_Edu_Infantil', 'Creche_Edu_Infantil', 'Pré-Escola_Edu_Infantil',
        'Total_Ensino_Fund', 'Anos Iniciais_Ensino_Fund',
        'Anos Finais_Ensino_Fund', 'Total_Ensino_Méd',
        'Ensino_Médio_Propedêutico', 'Ensino_Médio_Normal/Magistério',
        'Curso_Técnico_Integrado', 'Total10', 'Total11',
        'Associada ao Ensino Médio12', 'Curso Técnico Concomitante',
        'Curso Técnico Subsequente', 'Total13', 'Curso FIC Concomitante',
        'Curso FIC Integrado na Modalidade EJA14', 'Total_EJA',
        'Ensino Fundamental_EJA', 'Ensino Médio_EJA', 'Total_Educação_Especial',
        'Classes_Comuns_Educação_Especial',
        'Classes_Exclusivas_Educação_Especial']]

df_2 = df_s[['Total_Fem', 'Não Declarada_Fem', 'Branca_Fem', 'Preta_Fem',
        'Parda_Fem', 'Amarela_Fem', 'Indígena_Fem', 'Total_Masc',
        'Não Declarada_Masc', 'Branca_Masc', 'Preta_Masc', 'Parda_Masc',
        'Amarela_Masc', 'Indígena_Masc']]

df_3 = df_i [['Até 3 anos', '4 a 5 anos', '6 a 10 anos', '11 a 14 anos',
        '15 a 17 anos', '18 a 19 anos', '20 a 24 anos', '25 a 29 anos',
        '30 a 34 anos', '35 a 39 anos', '40 anos ou mais']]

# %%
# Concatenação dos DataFrames
df = pd.concat([df_t, df_1, df_2, df_3], axis=1)

# %%
# Visualização do df concatenado
df
# Out:
#      Ano Região Geográfica Unidade da Federação Total_Geral   Total_Urb  \
# 0   2018            Brasil               Brasil  48.455.867  42.982.279
# 1   2018             Norte                Norte   4.992.490   3.820.251
# 2   2018             Norte             Rondônia     428.929     364.763
# 3   2018             Norte                 Acre     284.061     202.003
# 4   2018             Norte             Amazonas   1.165.354     905.025
# ..   ...               ...                  ...         ...         ...
# 94  2022      Centro-Oeste         Centro-Oeste   3.642.951   3.408.128
# 95  2022      Centro-Oeste   Mato Grosso do Sul     667.842     610.130
# 96  2022      Centro-Oeste          Mato Grosso     892.534     787.811
# 97  2022      Centro-Oeste                Goiás   1.438.877   1.391.911
# 98  2022      Centro-Oeste     Distrito Federal     643.698     618.276
#
#     Federal_Urb Estadual_Urb Municipal_Urb Privada_Urb Total_Rural  ...  \
# 0       355.937   15.116.036    18.603.701   8.906.605   5.473.588  ...
# 1        44.265    1.558.439     1.765.537     452.010   1.172.239  ...
# 2         7.134      183.229       132.891      41.509      64.166  ...
# 3         2.776      123.599        63.209      12.419      82.058  ...
# 4        10.969      412.804       394.460      86.792     260.329  ...
# ..          ...          ...           ...         ...         ...  ...
# 94       27.385    1.384.982     1.330.047     665.714     234.823  ...
# 95        5.870      180.796       325.259      98.205      57.712  ...
# 96        6.595      321.339       354.985     104.892     104.723  ...
# 97        7.615      465.970       649.803     268.523      46.966  ...
# 98        7.305      416.877             -     194.094      25.422  ...
#
#    4 a 5 anos  6 a 10 anos 11 a 14 anos 15 a 17 anos 18 a 19 anos  \
# 0   5.051.157   13.976.552   11.758.610    8.281.372    1.979.448
# 1     499.541    1.519.511    1.270.916      853.540      247.094
# 2      44.567      128.739      108.702       77.922       19.375
# 3      26.589       79.739       66.137       46.071       12.530
# 4     116.887      361.936      298.930      202.325       56.275
# ..        ...          ...          ...          ...          ...
# 94    398.173    1.163.525      902.086      641.681      104.516
# 95     73.581      213.057      162.930      106.970       19.826
# 96    100.450      282.418      212.103      151.010       23.845
# 97    157.507      472.972      369.195      260.993       35.877
# 98     66.635      195.078      157.858      122.708       24.968
#
#    20 a 24 anos 25 a 29 anos 30 a 34 anos 35 a 39 anos 40 anos ou mais
# 0     1.393.843      612.041      464.691      410.618         947.346
# 1       185.942       74.285       53.774       41.834          75.162
# 2        13.219        5.793        4.374        3.300           4.791
# 3         9.599        5.118        4.835        5.055          16.881
# 4        44.358       18.617       13.069        9.693          15.607
# ..          ...          ...          ...          ...             ...
# 94       56.643       31.494       24.359       21.921          48.475
# 95       11.380        6.207        4.720        4.080           8.285
# 96       13.809        8.048        6.360        5.753          15.104
# 97       16.344       10.002        8.095        7.237          14.063
# 98       15.110        7.237        5.184        4.851          11.023
#
# [99 rows x 63 columns]

# %% [markdown]
# ## Backup 1

# %%
# Primeiro backup
dfback1 = df.copy()

# %% [markdown]
# ## Mongo DB

# %%
# Instalação da biblioteca do MongoDB
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 8.9 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 35.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.4.1

# %%
#Conector MongoDB
from pymongo import MongoClient

uri = "mongodb+srv://educacao13.opl7zu0.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"
client = MongoClient(uri, tls=True, tlsCertificateKeyFile='/content/X509-cert-622166640216179890.pem')

# %%
#Escolhendo a base de dados e coleção
db = client['pandasmongo']
collection = db['matriculas_bruto']

# %%
#Contagem dos documentos - na saída de código tem que dar zero
doc_count = collection.count_documents({})
print(doc_count)
# Out:
# 297

# %%
# Conversão para colocar no MongoDB
df_dict = df.to_dict("records")
collection.insert_many(df_dict)

# %%
# Checagem de valores no MongoDB
collection.count_documents({})
# Out:
# 396

# %%
#Checagem da coleção do MongoDB
for x in collection.find():
  print(x)

# %% [markdown]
# ## **Pré-Análise**

# %% [markdown]
# ### Visualização

# %%
# Visualização do df
df
# Out:
#      Ano Região Geográfica Unidade da Federação Total_Geral   Total_Urb  \
# 0   2018            Brasil               Brasil  48.455.867  42.982.279
# 1   2018             Norte                Norte   4.992.490   3.820.251
# 2   2018             Norte             Rondônia     428.929     364.763
# 3   2018             Norte                 Acre     284.061     202.003
# 4   2018             Norte             Amazonas   1.165.354     905.025
# ..   ...               ...                  ...         ...         ...
# 94  2022      Centro-Oeste         Centro-Oeste   3.642.951   3.408.128
# 95  2022      Centro-Oeste   Mato Grosso do Sul     667.842     610.130
# 96  2022      Centro-Oeste          Mato Grosso     892.534     787.811
# 97  2022      Centro-Oeste                Goiás   1.438.877   1.391.911
# 98  2022      Centro-Oeste     Distrito Federal     643.698     618.276
#
#     Federal_Urb Estadual_Urb Municipal_Urb Privada_Urb Total_Rural  ...  \
# 0       355.937   15.116.036    18.603.701   8.906.605   5.473.588  ...
# 1        44.265    1.558.439     1.765.537     452.010   1.172.239  ...
# 2         7.134      183.229       132.891      41.509      64.166  ...
# 3         2.776      123.599        63.209      12.419      82.058  ...
# 4        10.969      412.804       394.460      86.792     260.329  ...
# ..          ...          ...           ...         ...         ...  ...
# 94       27.385    1.384.982     1.330.047     665.714     234.823  ...
# 95        5.870      180.796       325.259      98.205      57.712  ...
# 96        6.595      321.339       354.985     104.892     104.723  ...
# 97        7.615      465.970       649.803     268.523      46.966  ...
# 98        7.305      416.877             -     194.094      25.422  ...
#
#    4 a 5 anos  6 a 10 anos 11 a 14 anos 15 a 17 anos 18 a 19 anos  \
# 0   5.051.157   13.976.552   11.758.610    8.281.372    1.979.448
# 1     499.541    1.519.511    1.270.916      853.540      247.094
# 2      44.567      128.739      108.702       77.922       19.375
# 3      26.589       79.739       66.137       46.071       12.530
# 4     116.887      361.936      298.930      202.325       56.275
# ..        ...          ...          ...          ...          ...
# 94    398.173    1.163.525      902.086      641.681      104.516
# 95     73.581      213.057      162.930      106.970       19.826
# 96    100.450      282.418      212.103      151.010       23.845
# 97    157.507      472.972      369.195      260.993       35.877
# 98     66.635      195.078      157.858      122.708       24.968
#
#    20 a 24 anos 25 a 29 anos 30 a 34 anos 35 a 39 anos 40 anos ou mais
# 0     1.393.843      612.041      464.691      410.618         947.346
# 1       185.942       74.285       53.774       41.834          75.162
# 2        13.219        5.793        4.374        3.300           4.791
# 3         9.599        5.118        4.835        5.055          16.881
# 4        44.358       18.617       13.069        9.693          15.607
# ..          ...          ...          ...          ...             ...
# 94       56.643       31.494       24.359       21.921          48.475
# 95       11.380        6.207        4.720        4.080           8.285
# 96       13.809        8.048        6.360        5.753          15.104
# 97       16.344       10.002        8.095        7.237          14.063
# 98       15.110        7.237        5.184        4.851          11.023
#
# [99 rows x 63 columns]

# %% [markdown]
# # **Tratamento**
#
# Retiradas de colunas que não estão relacionadas ao outro dataframe (df de Rendimento) analisado neste trabalho.

# %% [markdown]
# ## Drop e Renomeação das colunas/atributos

# %%
# Dropando colunas
df.drop(['Região Geográfica', 'Total_Geral', 'Total_Edu_Infantil', 'Creche_Edu_Infantil', 'Pré-Escola_Edu_Infantil',
         'Ensino_Médio_Propedêutico', 'Ensino_Médio_Normal/Magistério', 'Curso_Técnico_Integrado','Total10','Total11',
         'Associada ao Ensino Médio12','Curso Técnico Concomitante','Curso Técnico Subsequente','Total13',
         'Curso FIC Concomitante','Curso FIC Integrado na Modalidade EJA14','Total_EJA','Ensino Fundamental_EJA',
         'Ensino Médio_EJA','Total_Educação_Especial', 'Ensino Médio_EJA','Total_Educação_Especial',
         'Classes_Comuns_Educação_Especial','Classes_Exclusivas_Educação_Especial', 'Região Geográfica',
         'Até 3 anos','4 a 5 anos','18 a 19 anos','20 a 24 anos','25 a 29 anos','30 a 34 anos','35 a 39 anos',
         '40 anos ou mais'],axis=1,inplace=True)

# %%
# Renomeação das colunas
df.rename(columns={'Ano' : 'ano',
                        'Unidade da Federação' : 'und_geografica',
                        'Total_Ensino_Fund' : 'total_fund',
                        'Anos Iniciais_Ensino_Fund': 'anos_iniciais',
                        'Anos Finais_Ensino_Fund' : 'anos_finais',
                        'Total_Ensino_Méd':'total_medio',
                        'Total_Fem' : 'total_fem',
                        'Total_Masc' : 'total_masc',
                        'Não Declarada_Fem' : 'nao_dec_fem',
                        'Não Declarada_Masc' : 'nao_dec_masc',
                        'Branca_Fem' : 'branca_fem',
                        'Branca_Masc' : 'branca_masc',
                        'Preta_Fem' : 'preta_fem',
                        'Preta_Masc' : 'preta_masc',
                        'Parda_Fem' : 'parda_fem',
                        'Parda_Masc' : 'parda_masc',
                        'Amarela_Fem' : 'amarela_fem',
                        'Amarela_Masc' : 'amarela_masc',
                        'Indígena_Fem' : 'indígena_fem',
                        'Indígena_Masc' : 'indígena_masc',
                        'Total_Urb' : 'total_urb',
                        'Total_Rural' : 'total_rural',
                        'Federal_Urb' : 'federal_urb',
                        'Federal_Rural' : 'federal_rural',
                        'Municipal_Urb' : 'municipal_urb',
                        'Municipal_Rural' : 'municipal_rural',
                        'Privada_Urb' : 'privada_urb',
                        'Privada_Rural' : 'privada_rural',
                        'Estadual_Urb' : 'estadual_urb',
                        'Estadual_Rural' : 'estadual_rural',
                        '6 a 10 anos':'6_10_anos',
                        '11 a 14 anos':'11_14_anos',
                        '15 a 17 anos':'15_17_anos'}, inplace=True)

# %%
# Verificando o DataFrame após a exclusão e renomeação das colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ano              99 non-null     int64
#  1   und_geografica   99 non-null     object
#  2   total_urb        99 non-null     object
#  3   federal_urb      99 non-null     float64
#  4   estadual_urb     99 non-null     object
#  5   municipal_urb    99 non-null     object
#  6   privada_urb      99 non-null     object
#  7   total_rural      99 non-null     object
#  8   federal_rural    99 non-null     object
#  9   estadual_rural   99 non-null     float64
#  10  municipal_rural  99 non-null     object
#  11  privada_rural    99 non-null     object
#  12  total_fund       99 non-null     object
#  13  anos_iniciais    99 non-null     object
#  14  anos_finais      99 non-null     object
#  15  total_medio      99 non-null     object
#  16  total_fem        99 non-null     object
#  17  nao_dec_fem      99 non-null     object
#  18  branca_fem       99 non-null     object
#  19  preta_fem        99 non-null     float64
#  20  parda_fem        99 non-null     object
#  21  amarela_fem      99 non-null     float64
#  22  indígena_fem     99 non-null     float64
#  23  total_masc       99 non-null     object
#  24  nao_dec_masc     99 non-null     object
#  25  branca_masc      99 non-null     object
#  26  preta_masc       99 non-null     float64
#  27  parda_masc       99 non-null     object
#  28  amarela_masc     99 non-null     float64
#  29  indígena_masc    99 non-null     float64
#  30  6_10_anos        99 non-null     object
#  31  11_14_anos       99 non-null     object
#  32  15_17_anos       99 non-null     object
# dtypes: float64(8), int64(1), object(24)
# memory usage: 25.6+ KB

# %%
# Verificação do tamanho e tipo do DF
print(f'Linhas: {df.shape[0]}')
print(f'Colunas: {df.shape[1]}')
df.dtypes
# Out:
# Linhas: 99
# Colunas: 33
# ano                  int64
# und_geografica      object
# total_urb           object
# federal_urb        float64
# estadual_urb        object
# municipal_urb       object
# privada_urb         object
# total_rural         object
# federal_rural       object
# estadual_rural     float64
# municipal_rural     object
# privada_rural       object
# total_fund          object
# anos_iniciais       object
# anos_finais         object
# total_medio         object
# total_fem           object
# nao_dec_fem         object
# branca_fem          object
# preta_fem          float64
# parda_fem           object
# amarela_fem        float64
# indígena_fem       float64
# total_masc          object
# nao_dec_masc        object
# branca_masc         object
# preta_masc         float64
# parda_masc          object
# amarela_masc       float64
# indígena_masc      float64
# 6_10_anos           object
# 11_14_anos          object
# 15_17_anos          object
# dtype: object

# %% [markdown]
# ## Verificação e Tratamento de dados nulos

# %%
# Verificação da existência de dados nulos
df.isnull().sum()
# Out:
# ano                0
# und_geografica     0
# total_urb          0
# federal_urb        0
# estadual_urb       0
# municipal_urb      0
# privada_urb        0
# total_rural        0
# federal_rural      0
# estadual_rural     0
# municipal_rural    0
# privada_rural      0
# total_fund         0
# anos_iniciais      0
# anos_finais        0
# total_medio        0
# total_fem          0
# nao_dec_fem        0
# branca_fem         0
# preta_fem          0
# parda_fem          0
# amarela_fem        0
# indígena_fem       0
# total_masc         0
# nao_dec_masc       0
# branca_masc        0
# preta_masc         0
# parda_masc         0
# amarela_masc       0
# indígena_masc      0
# 6_10_anos          0
# 11_14_anos         0
# 15_17_anos         0
# dtype: int64

# %% [markdown]
# ## Transformação de tipos adequados dos dados

# %%
# Verificação do tipo atual
df.dtypes
# Out:
# ano                  int64
# und_geografica      object
# total_urb           object
# federal_urb        float64
# estadual_urb        object
# municipal_urb       object
# privada_urb         object
# total_rural         object
# federal_rural       object
# estadual_rural     float64
# municipal_rural     object
# privada_rural       object
# total_fund          object
# anos_iniciais       object
# anos_finais         object
# total_medio         object
# total_fem           object
# nao_dec_fem         object
# branca_fem          object
# preta_fem          float64
# parda_fem           object
# amarela_fem        float64
# indígena_fem       float64
# total_masc          object
# nao_dec_masc        object
# branca_masc         object
# preta_masc         float64
# parda_masc          object
# amarela_masc       float64
# indígena_masc      float64
# 6_10_anos           object
# 11_14_anos          object
# 15_17_anos          object
# dtype: object

# %%
# Alterando os tipos para str e retirando os pontos "."
df['ano'] = df['ano'].astype(int)
df['und_geografica'] = df['und_geografica'].astype(str)
df['total_fund'] = df['total_fund'].astype(str)
df['total_fund'] = df['total_fund'].str.replace('.', '')
df['anos_iniciais'] = df['anos_iniciais'].astype(str)
df['anos_iniciais'] = df['anos_iniciais'].str.replace('.', '')
df['anos_finais'] = df['anos_finais'].astype(str)
df['anos_finais'] = df['anos_finais'].str.replace('.', '')
df['total_medio'] = df['total_medio'].astype(str)
df['total_medio'] = df['total_medio'].str.replace('.', '')
df['total_fem'] = df['total_fem'].astype(str)
df['total_fem'] = df['total_fem'].str.replace('.', '')
df['total_masc'] = df['total_masc'].astype(str)
df['total_masc'] = df['total_masc'].str.replace('.', '')
df['nao_dec_fem'] = df['nao_dec_fem'].astype(str)
df['nao_dec_fem'] = df['nao_dec_fem'].str.replace('.', '')
df['nao_dec_masc'] = df['nao_dec_masc'].astype(str)
df['nao_dec_masc'] = df['nao_dec_masc'].str.replace('.', '')
df['branca_fem'] = df['branca_fem'].astype(str)
df['branca_fem'] = df['branca_fem'].str.replace('.', '')
df['branca_masc'] = df['branca_masc'].astype(str)
df['branca_masc'] = df['branca_masc'].str.replace('.', '')
df['preta_fem'] = df['preta_fem'].astype(str)
df['preta_fem'] = df['preta_fem'].str.replace('.', '')
df['preta_masc'] = df['preta_masc'].astype(str)
df['preta_masc'] = df['preta_masc'].str.replace('.', '')
df['parda_fem'] = df['parda_fem'].astype(str)
df['parda_fem'] = df['parda_fem'].str.replace('.', '')
df['parda_masc'] = df['parda_masc'].astype(str)
df['parda_masc'] = df['parda_masc'].str.replace('.', '')
df['amarela_fem'] = df['amarela_fem'].astype(str)
df['amarela_fem'] = df['amarela_fem'].str.replace('.', '')
df['amarela_masc'] = df['amarela_masc'].astype(str)
df['amarela_masc'] = df['amarela_masc'].str.replace('.', '')
df['indígena_fem'] = df['indígena_fem'].astype(str)
df['indígena_fem'] = df['indígena_fem'].str.replace('.', '')
df['indígena_masc'] = df['indígena_masc'].astype(str)
df['indígena_masc'] = df['indígena_masc'].str.replace('.', '')
df['federal_urb'] = df['federal_urb'].astype(str)
df['federal_urb'] = df['federal_urb'].str.replace('.', '')
df['estadual_rural'] = df['estadual_rural'].astype(str)
df['estadual_rural'] = df['estadual_rural'].str.replace('.', '')
df['total_urb'] = df['total_urb'].str.replace('.', '')
df['total_rural'] = df['total_rural'].str.replace('.', '')
df['federal_rural'] = df['federal_rural'].str.replace('.', '')
df['estadual_urb'] = df['estadual_urb'].str.replace('.', '')
df['municipal_urb'] = df['municipal_urb'].str.replace('.', '')
df['municipal_rural'] = df['municipal_rural'].str.replace('.', '')
df['privada_urb'] = df['privada_urb'].str.replace('.', '')
df['privada_rural'] = df['privada_rural'].str.replace('.', '')
df['6_10_anos'] = df['6_10_anos'].astype(str)
df['6_10_anos'] = df['6_10_anos'].str.replace('.', '')
df['11_14_anos'] = df['11_14_anos'].astype(str)
df['11_14_anos'] = df['11_14_anos'].str.replace('.', '')
df['15_17_anos'] = df['15_17_anos'].astype(str)
df['15_17_anos'] = df['15_17_anos'].str.replace('.', '')

# %%
# Trocando os hífens por NaN
df.replace(['-'],np.NaN,inplace=True)

# %%
# Atualização das colunas e transformação para números inteiros
df['total_fund'] = pd.to_numeric(df['total_fund'])
df['anos_iniciais'] = pd.to_numeric(df['anos_iniciais'])
df['anos_finais'] = pd.to_numeric(df['anos_finais'])
df['total_medio'] = pd.to_numeric(df['total_medio'])
df['total_fem'] =  pd.to_numeric(df['total_fem'])
df['total_masc'] = pd.to_numeric(df['total_masc'])
df['nao_dec_fem'] = pd.to_numeric(df['nao_dec_fem'])
df['nao_dec_masc'] = pd.to_numeric(df['nao_dec_masc'])
df['branca_fem'] = pd.to_numeric(df['branca_fem'])
df['branca_masc'] = pd.to_numeric(df['branca_masc'])
df['preta_fem'] =  pd.to_numeric(df['preta_fem'])
df['preta_masc'] = pd.to_numeric(df['preta_masc'])
df['parda_fem'] =  pd.to_numeric(df['parda_fem'])
df['parda_masc'] = pd.to_numeric(df['parda_masc'])
df['amarela_fem'] = pd.to_numeric(df['amarela_fem'])
df['amarela_masc'] = pd.to_numeric(df['amarela_masc'])
df['indígena_fem'] = pd.to_numeric(df['indígena_fem'])
df['indígena_masc'] = pd.to_numeric(df['indígena_masc'])
df['total_urb'] =  pd.to_numeric(df['total_urb'])
df['total_rural'] = pd.to_numeric(df['total_rural'])
df['federal_urb'] = pd.to_numeric(df['federal_urb'])
df['federal_rural'] = pd.to_numeric(df['federal_rural'])
df['estadual_urb'] = pd.to_numeric(df['estadual_urb'])
df['estadual_rural'] = pd.to_numeric(df['estadual_rural'])
df['municipal_urb'] = pd.to_numeric(df['municipal_urb'])
df['municipal_rural'] = pd.to_numeric(df['municipal_rural'])
df['privada_urb'] = pd.to_numeric(df['privada_urb'])
df['privada_rural'] = pd.to_numeric(df['privada_rural'])
df['6_10_anos'] =  pd.to_numeric(df['6_10_anos'])
df['11_14_anos'] =  pd.to_numeric(df['11_14_anos'])
df['15_17_anos'] =  pd.to_numeric(df['15_17_anos'])

# %%
# Visualização do df
df
# Out:
#      ano      und_geografica  total_urb  federal_urb  estadual_urb  \
# 0   2018              Brasil   42982279       355937      15116036
# 1   2018               Norte    3820251        44265       1558439
# 2   2018            Rondônia     364763         7134        183229
# 3   2018                Acre     202003         2776        123599
# 4   2018            Amazonas     905025        10969        412804
# ..   ...                 ...        ...          ...           ...
# 94  2022        Centro-Oeste    3408128        27385       1384982
# 95  2022  Mato Grosso do Sul     610130          587        180796
# 96  2022         Mato Grosso     787811         6595        321339
# 97  2022               Goiás    1391911         7615        465970
# 98  2022    Distrito Federal     618276         7305        416877
#
#     municipal_urb  privada_urb  total_rural  federal_rural  estadual_rural  \
# 0      18603701.0      8906605      5473588        55141.0           83038
# 1       1765537.0       452010      1172239         3751.0          209812
# 2        132891.0        41509        64166         1208.0           13301
# 3         63209.0        12419        82058            NaN           46214
# 4        394460.0        86792       260329          551.0           48459
# ..            ...          ...          ...            ...             ...
# 94      1330047.0       665714       234823         6536.0           93019
# 95       325259.0        98205        57712         1235.0           13934
# 96       354985.0       104892       104723         1974.0           46819
# 97       649803.0       268523        46966         2352.0            9411
# 98            NaN       194094        25422          975.0           22855
#
#     ...  total_masc  nao_dec_masc  branca_masc  preta_masc  parda_masc  \
# 0   ...    24632863       6961968      7734773      866697     8826429
# 1   ...     2545128        807269       244596       48123     1364518
# 2   ...      218642         54558        46351        5557      108208
# 3   ...      144628         52037        11888        1797       73174
# 4   ...      587480         86732        47043        5766      407493
# ..  ...         ...           ...          ...         ...         ...
# 94  ...     1845859        742139       417979       36011      618309
# 95  ...      340066         32838       142622        5962      143310
# 96  ...      451178        276193        58419        6266       99428
# 97  ...      730494        318474       136076       14386      257946
# 98  ...      324121        114634        80862        9397      117625
#
#     amarela_masc  indígena_masc  6_10_anos  11_14_anos  15_17_anos
# 0          82927         160069   13976552    11758610     8281372
# 1           6584          74038    1519511     1270916      853540
# 2           1166           2802     128739      108702       77922
# 3           5400           5192      79739       66137       46071
# 4           8440          39602     361936      298930      202325
# ..           ...            ...        ...         ...         ...
# 94          6047          25374    1163525      902086      641681
# 95          9140           1442     213057      162930      106970
# 96          7380          10134     282418      212103      151010
# 97          3105           5070     472972      369195      260993
# 98           129           3130     195078      157858      122708
#
# [99 rows x 33 columns]

# %%
# Conferindo as alterações
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ano              99 non-null     int64
#  1   und_geografica   99 non-null     object
#  2   total_urb        99 non-null     int64
#  3   federal_urb      99 non-null     int64
#  4   estadual_urb     99 non-null     int64
#  5   municipal_urb    96 non-null     float64
#  6   privada_urb      99 non-null     int64
#  7   total_rural      99 non-null     int64
#  8   federal_rural    90 non-null     float64
#  9   estadual_rural   99 non-null     int64
#  10  municipal_rural  96 non-null     float64
#  11  privada_rural    96 non-null     float64
#  12  total_fund       99 non-null     int64
#  13  anos_iniciais    99 non-null     int64
#  14  anos_finais      99 non-null     int64
#  15  total_medio      99 non-null     int64
#  16  total_fem        99 non-null     int64
#  17  nao_dec_fem      99 non-null     int64
#  18  branca_fem       99 non-null     int64
#  19  preta_fem        99 non-null     int64
#  20  parda_fem        99 non-null     int64
#  21  amarela_fem      99 non-null     int64
#  22  indígena_fem     99 non-null     int64
#  23  total_masc       99 non-null     int64
#  24  nao_dec_masc     99 non-null     int64
#  25  branca_masc      99 non-null     int64
#  26  preta_masc       99 non-null     int64
#  27  parda_masc       99 non-null     int64
#  28  amarela_masc     99 non-null     int64
#  29  indígena_masc    99 non-null     int64
#  30  6_10_anos        99 non-null     int64
#  31  11_14_anos       99 non-null     int64
#  32  15_17_anos       99 non-null     int64
# dtypes: float64(4), int64(28), object(1)
# memory usage: 25.6+ KB

# %%
# Visualização do df
df.head()
# Out:
#     ano und_geografica  total_urb  federal_urb  estadual_urb  municipal_urb  \
# 0  2018         Brasil   42982279       355937      15116036     18603701.0
# 1  2018          Norte    3820251        44265       1558439      1765537.0
# 2  2018       Rondônia     364763         7134        183229       132891.0
# 3  2018           Acre     202003         2776        123599        63209.0
# 4  2018       Amazonas     905025        10969        412804       394460.0
#
#    privada_urb  total_rural  federal_rural  estadual_rural  ...  total_masc  \
# 0      8906605      5473588        55141.0           83038  ...    24632863
# 1       452010      1172239         3751.0          209812  ...     2545128
# 2        41509        64166         1208.0           13301  ...      218642
# 3        12419        82058            NaN           46214  ...      144628
# 4        86792       260329          551.0           48459  ...      587480
#
#    nao_dec_masc  branca_masc  preta_masc  parda_masc  amarela_masc  \
# 0       6961968      7734773      866697     8826429         82927
# 1        807269       244596       48123     1364518          6584
# 2         54558        46351        5557      108208          1166
# 3         52037        11888        1797       73174          5400
# 4         86732        47043        5766      407493          8440
#
#    indígena_masc  6_10_anos  11_14_anos  15_17_anos
# 0         160069   13976552    11758610     8281372
# 1          74038    1519511     1270916      853540
# 2           2802     128739      108702       77922
# 3           5192      79739       66137       46071
# 4          39602     361936      298930      202325
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Backup 2

# %%
# Segundo backup
dfback2 = df.copy()

# %% [markdown]
# ## Validação de dados

# %%
# Verificando os valores unicos da coluna 'ano'
print(pd.unique(df['ano']))
# Out:
# [2018 2020 2022]

# %%
# Verificando os valores unicos da coluna 'und_geografica'
print(pd.unique(df['und_geografica']))
# Out:
# ['Brasil' 'Norte' 'Rondônia' 'Acre' 'Amazonas' 'Roraima' 'Pará' 'Amapá'
#  'Tocantins' 'Nordeste' 'Maranhão' 'Piauí' 'Ceará' 'Rio Grande do Norte'
#  'Paraíba' 'Pernambuco' 'Alagoas' 'Sergipe' 'Bahia' 'Sudeste'
#  'Minas Gerais' 'Espírito Santo' 'Rio de Janeiro' 'São Paulo' 'Sul'
#  'Paraná' 'Santa Catarina' 'Rio Grande do Sul' 'Centro-Oeste'
#  'Mato Grosso do Sul' 'Mato Grosso' 'Goiás' 'Distrito Federal']

# %%
# Cálculo da porcentagem de valores nulo, ausentes em cada coluna
porcentagem_nulos = (df.isnull().sum() / len(df)) * 100

# Exibição da porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# ano                0.0
# und_geografica     0.0
# total_urb          0.0
# federal_urb        0.0
# estadual_urb       0.0
# municipal_urb      3.0
# privada_urb        0.0
# total_rural        0.0
# federal_rural      9.1
# estadual_rural     0.0
# municipal_rural    3.0
# privada_rural      3.0
# total_fund         0.0
# anos_iniciais      0.0
# anos_finais        0.0
# total_medio        0.0
# total_fem          0.0
# nao_dec_fem        0.0
# branca_fem         0.0
# preta_fem          0.0
# parda_fem          0.0
# amarela_fem        0.0
# indígena_fem       0.0
# total_masc         0.0
# nao_dec_masc       0.0
# branca_masc        0.0
# preta_masc         0.0
# parda_masc         0.0
# amarela_masc       0.0
# indígena_masc      0.0
# 6_10_anos          0.0
# 11_14_anos         0.0
# 15_17_anos         0.0
# dtype: float64

# %% [markdown]
# ## **Validação dos dados via Pandera**

# %%
# Visualização do tipo de cada coluna/atributo
df.dtypes
# Out:
# ano                  int64
# und_geografica      object
# total_urb            int64
# federal_urb          int64
# estadual_urb         int64
# municipal_urb      float64
# privada_urb          int64
# total_rural          int64
# federal_rural      float64
# estadual_rural       int64
# municipal_rural    float64
# privada_rural      float64
# total_fund           int64
# anos_iniciais        int64
# anos_finais          int64
# total_medio          int64
# total_fem            int64
# nao_dec_fem          int64
# branca_fem           int64
# preta_fem            int64
# parda_fem            int64
# amarela_fem          int64
# indígena_fem         int64
# total_masc           int64
# nao_dec_masc         int64
# branca_masc          int64
# preta_masc           int64
# parda_masc           int64
# amarela_masc         int64
# indígena_masc        int64
# 6_10_anos            int64
# 11_14_anos           int64
# 15_17_anos           int64
# dtype: object

# %%
# Visualização das colunas do df
df.columns
# Out:
# Index(['ano', 'und_geografica', 'total_urb', 'federal_urb', 'estadual_urb',
#        'municipal_urb', 'privada_urb', 'total_rural', 'federal_rural',
#        'estadual_rural', 'municipal_rural', 'privada_rural', 'total_fund',
#        'anos_iniciais', 'anos_finais', 'total_medio', 'total_fem',
#        'nao_dec_fem', 'branca_fem', 'preta_fem', 'parda_fem', 'amarela_fem',
#        'indígena_fem', 'total_masc', 'nao_dec_masc', 'branca_masc',
#        'preta_masc', 'parda_masc', 'amarela_masc', 'indígena_masc',
#        '6_10_anos', '11_14_anos', '15_17_anos'],
#       dtype='object')

# %%
# Definição do esquema de validação no Pandera

schema = pa.DataFrameSchema({'ano': pa.Column(pa.Int),
                            'und_geografica': pa.Column(pa.String),
                            'total_urb': pa.Column(pa.Int),
                            'federal_urb': pa.Column(pa.Int),
                            'estadual_urb': pa.Column(pa.Int),
                            'municipal_urb': pa.Column(pa.Float, coerce=True, nullable=True),
                            'privada_urb': pa.Column(pa.Int),
                            'total_rural': pa.Column(pa.Int),
                            'federal_rural': pa.Column(pa.Float, coerce=True, nullable=True),
                            'estadual_rural': pa.Column(pa.Int),
                            'municipal_rural': pa.Column(pa.Float, coerce=True, nullable=True),
                            'privada_rural': pa.Column(pa.Float, coerce=True, nullable=True),
                            'total_fund': pa.Column(pa.Int),
                            'anos_iniciais': pa.Column(pa.Int),
                            'anos_finais': pa.Column(pa.Int),
                            'total_medio': pa.Column(pa.Int),
                            'total_fem': pa.Column(pa.Int),
                            'nao_dec_fem': pa.Column(pa.Int),
                            'branca_fem': pa.Column(pa.Int),
                            'preta_fem': pa.Column(pa.Int),
                            'parda_fem': pa.Column(pa.Int),
                            'amarela_fem': pa.Column(pa.Int),
                            'indígena_fem': pa.Column(pa.Int),
                            'total_masc': pa.Column(pa.Int),
                            'nao_dec_masc': pa.Column(pa.Int),
                            'branca_masc': pa.Column(pa.Int),
                            'preta_masc': pa.Column(pa.Int),
                            'parda_masc': pa.Column(pa.Int),
                            'amarela_masc': pa.Column(pa.Int),
                            'indígena_masc': pa.Column(pa.Int),
                            '6_10_anos': pa.Column(pa.Int),
                            '11_14_anos': pa.Column(pa.Int),
                            '15_17_anos': pa.Column(pa.Int),
                            })
# Validação do DataFrame
schema.validate(df)
# Out:
#      ano      und_geografica  total_urb  federal_urb  estadual_urb  \
# 0   2018              Brasil   42982279       355937      15116036
# 1   2018               Norte    3820251        44265       1558439
# 2   2018            Rondônia     364763         7134        183229
# 3   2018                Acre     202003         2776        123599
# 4   2018            Amazonas     905025        10969        412804
# ..   ...                 ...        ...          ...           ...
# 94  2022        Centro-Oeste    3408128        27385       1384982
# 95  2022  Mato Grosso do Sul     610130          587        180796
# 96  2022         Mato Grosso     787811         6595        321339
# 97  2022               Goiás    1391911         7615        465970
# 98  2022    Distrito Federal     618276         7305        416877
#
#     municipal_urb  privada_urb  total_rural  federal_rural  estadual_rural  \
# 0      18603701.0      8906605      5473588        55141.0           83038
# 1       1765537.0       452010      1172239         3751.0          209812
# 2        132891.0        41509        64166         1208.0           13301
# 3         63209.0        12419        82058            NaN           46214
# 4        394460.0        86792       260329          551.0           48459
# ..            ...          ...          ...            ...             ...
# 94      1330047.0       665714       234823         6536.0           93019
# 95       325259.0        98205        57712         1235.0           13934
# 96       354985.0       104892       104723         1974.0           46819
# 97       649803.0       268523        46966         2352.0            9411
# 98            NaN       194094        25422          975.0           22855
#
#     ...  total_masc  nao_dec_masc  branca_masc  preta_masc  parda_masc  \
# 0   ...    24632863       6961968      7734773      866697     8826429
# 1   ...     2545128        807269       244596       48123     1364518
# 2   ...      218642         54558        46351        5557      108208
# 3   ...      144628         52037        11888        1797       73174
# 4   ...      587480         86732        47043        5766      407493
# ..  ...         ...           ...          ...         ...         ...
# 94  ...     1845859        742139       417979       36011      618309
# 95  ...      340066         32838       142622        5962      143310
# 96  ...      451178        276193        58419        6266       99428
# 97  ...      730494        318474       136076       14386      257946
# 98  ...      324121        114634        80862        9397      117625
#
#     amarela_masc  indígena_masc  6_10_anos  11_14_anos  15_17_anos
# 0          82927         160069   13976552    11758610     8281372
# 1           6584          74038    1519511     1270916      853540
# 2           1166           2802     128739      108702       77922
# 3           5400           5192      79739       66137       46071
# 4           8440          39602     361936      298930      202325
# ..           ...            ...        ...         ...         ...
# 94          6047          25374    1163525      902086      641681
# 95          9140           1442     213057      162930      106970
# 96          7380          10134     282418      212103      151010
# 97          3105           5070     472972      369195      260993
# 98           129           3130     195078      157858      122708
#
# [99 rows x 33 columns]

# %% [markdown]
# ## **Validação utilizando o PySpark**

# %% [markdown]
# ##Instalações e importações do PySpark

# %%
#Instalando os requisitos necessarios
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
#Importando ferramentas
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
#Criando a sessão clusterizada do PySpark
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
from pyspark.sql.functions import regexp_replace
spark.conf.set("spark.sql.repl.eagerEval.enabled", True)
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ca48e550a7cc:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# Validação

# %%
# Exportação do dataframe do Pandas para o PySpark
df_py = spark.createDataFrame(df)
# Out:
# /content/spark-3.1.1-bin-hadoop3.2/python/pyspark/sql/pandas/conversion.py:331: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# Visualização do dataframe pelo PySpark
df_py.show()
# Out:
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# | ano|     und_geografica|total_urb|federal_urb|estadual_urb|municipal_urb|privada_urb|total_rural|federal_rural|estadual_rural|municipal_rural|privada_rural|total_fund|anos_iniciais|anos_finais|total_medio|total_fem|nao_dec_fem|branca_fem|preta_fem|parda_fem|amarela_fem|indígena_fem|total_masc|nao_dec_masc|branca_masc|preta_masc|parda_masc|amarela_masc|indígena_masc|6_10_anos|11_14_anos|15_17_anos|
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# |2018|             Brasil| 42982279|     355937|    15116036|  1.8603701E7|    8906605|    5473588|      55141.0|         83038|      4499423.0|      88644.0|  27183970|     15176420|   12007550|    7709929| 23823004|    6702314|   7645543|   799424|  8441075|      81019|      153629|  24632863|     6961968|    7734773|    866697|   8826429|       82927|       160069| 13976552|  11758610|   8281372|
# |2018|              Norte|  3820251|      44265|     1558439|    1765537.0|     452010|    1172239|       3751.0|        209812|       951067.0|       7609.0|   3051017|      1756349|    1294668|     783745|  2447362|     764862|    255087|     4094|  1310064|       6556|       69853|   2545128|      807269|     244596|     48123|   1364518|        6584|        74038|  1519511|   1270916|    853540|
# |2018|           Rondônia|   364763|       7134|      183229|     132891.0|      41509|      64166|       1208.0|         13301|        46970.0|       2687.0|    269626|       154275|     115351|      59573|   210287|      51547|     47716|     4586|   102649|       1152|        2637|    218642|       54558|      46351|      5557|    108208|        1166|         2802|   128739|    108702|     77922|
# |2018|               Acre|   202003|       2776|      123599|      63209.0|      12419|      82058|          NaN|         46214|        35844.0|          NaN|    157646|        92305|      65341|      38141|   139433|      51045|     12334|     1418|    69144|       5000|        4992|    144628|       52037|      11888|      1797|     73174|        5400|         5192|    79739|     66137|     46071|
# |2018|           Amazonas|   905025|      10969|      412804|     394460.0|      86792|     260329|        551.0|         48459|       210766.0|        553.0|    705007|       405108|     299899|     205698|   577874|      85432|     49753|     5206|   399077|       8960|        3751|    587480|       86732|      47043|      5766|    407493|        8440|        39602|   361936|    298930|    202325|
# |2018|            Roraima|   118350|       2073|       51196|      49643.0|      15438|      38505|        655.0|         22112|        15714.0|         24.0|     96582|        53790|      42792|      22191|    76988|      19784|      7670|     1027|    38117|       1310|       10259|     79867|       20553|       7331|      1058|     39922|        1330|         1087|    52034|     39811|     25985|
# |2018|               Pará|  1687179|      13578|      545962|     896649.0|     230990|     641260|        462.0|         38987|       598819.0|       2992.0|   1439788|       833802|     605986|     359331|  1135941|     495275|     89729|    19087|   521218|       2373|        8259|   1192498|      527768|      85559|     22539|    545138|        2303|         9191|   705604|    597004|    390724|
# |2018|              Amapá|   185820|       3358|       98279|      61377.0|      22806|      40351|          NaN|         26136|        13855.0|        360.0|    136185|        81103|      55082|      35427|   111049|      28055|     13521|       28|    63744|       2340|        2695|    115122|       29575|      12456|      3336|     66626|        2700|         2859|    70420|     57504|     42249|
# |2018|          Tocantins|   357111|       4377|      143370|     167308.0|      42056|      45570|        875.0|         14603|        29099.0|        993.0|    246183|       135966|     110217|      63384|   195790|      33724|     34364|     6816|   116115|        127|        3501|    206891|       36046|      33968|       807|    123957|        1328|         3522|   121039|    102828|     68264|
# |2018|           Nordeste| 11207641|     115088|     3084696|    5580475.0|    2427382|    3005801|      17633.0|        231935|      2711659.0|      44574.0|   8039593|      4477690|    3561903|    2183818|  6986328|    2247480|    944810|   250061|  3481244|      26682|       36051|   7227114|     2338323|     921938|    273946|   3629144|       25971|        37792|  4017806|   3447895|   2421252|
# |2018|           Maranhão|  1336316|       1234|      286364|     827158.0|     210454|     694796|       3504.0|         59741|       610010.0|      21541.0|   1178949|       659333|     519616|     311830|   992593|     317796|     89617|    20176|   552645|       2687|        9672|   1038519|      335753|      86360|     22682|    580711|         282|        10193|   593716|    503020|    324164|
# |2018|              Piauí|   767519|      11021|      289846|     355018.0|     111634|     199406|        687.0|         12406|       186060.0|        253.0|    480126|       272639|     207487|     135125|   473466|     110110|     57189|    17458|   283987|       4181|        5410|    493459|      117611|      54042|      1996|    297286|        4022|         5380|   241348|    208320|    159082|
# |2018|              Ceará|  1788313|      10831|      399529|     959304.0|     418649|     387351|        547.0|         23727|       362036.0|       1041.0|   1198116|       659500|     538616|     367781|  1070391|     260342|    160194|    11586|   631239|       2996|        4034|   1105273|      268252|     155061|     13322|    661644|         282|         4174|   630766|    525890|    369972|
# |2018|Rio Grande do Norte|   706369|      20117|      212148|     304899.0|     169205|     123094|       4811.0|          8242|       108732.0|       1309.0|    467629|       259295|     208334|     124592|   405941|     153416|     98797|     6472|   145280|       1248|        7280|    423522|      162053|      97390|      7423|    154765|        1091|         8000|   233578|    198558|    141940|
# |2018|            Paraíba|   832628|       9919|      257407|     376349.0|     188953|     151593|        428.0|           169|       133568.0|        697.0|    556248|       308634|     247614|     141297|   482610|     134259|     96145|    10714|   236121|        244|        2931|    501611|      139313|      94101|      1204|    250768|        2357|         3032|   276778|    235605|    163238|
# |2018|         Pernambuco|  1889499|      14552|      531940|     829079.0|     513928|     362453|       3446.0|         52005|       299749.0|       7253.0|   1301930|       737135|     564795|     339909|  1109309|     418768|    202675|    26303|   449707|       3463|        8393|   1142643|      428828|     199469|     29413|    472495|         339|         9048|   656269|    561705|    391298|
# |2018|            Alagoas|   671847|      11492|      167542|     349138.0|     143675|     198732|          NaN|         11028|       186320.0|       1384.0|    490587|       272869|     217718|     118393|   431275|     126428|     57754|      913|   234408|       1366|        2189|    439304|      129258|      55260|     10541|    240701|        1292|         2252|   244255|    209192|    145424|
# |2018|            Sergipe|   433430|       3767|      146261|     163702.0|     119700|     110963|       1330.0|          6609|       101380.0|       1644.0|    331297|       185177|     146120|      77939|   267662|      81992|     30485|     7801|   145747|       1233|        4040|    276731|       84861|      29851|      8466|    151937|        1215|         4010|   159077|    139359|     96291|
# |2018|              Bahia|  2781720|      21049|      793659|    1415828.0|     551184|     777413|       2880.0|         41277|       723804.0|       9452.0|   2034711|      1123108|     911603|     566952|  1753081|     644369|    151954|   140421|   802110|       7068|        7159|   1806052|      672394|     150404|    150099|    818837|        6964|         7354|   982019|    866246|    629843|
# |2018|            Sudeste| 18415002|     106536|     6622676|    7458143.0|    4227647|     659938|      19763.0|        159872|       453185.0|      27118.0|  10384471|      5814430|    4570041|    3151377|  9398720|    2255191|   4015852|   398327|  2686185|      31245|        1192|   9676220|     2307308|    4089831|    426504|   2807819|       32803|        11955|  5479283|   4561962|   3284899|
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# only showing top 20 rows

# %%
# Visualização do tipo do df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ano              99 non-null     int64
#  1   und_geografica   99 non-null     object
#  2   total_urb        99 non-null     int64
#  3   federal_urb      99 non-null     int64
#  4   estadual_urb     99 non-null     int64
#  5   municipal_urb    96 non-null     float64
#  6   privada_urb      99 non-null     int64
#  7   total_rural      99 non-null     int64
#  8   federal_rural    90 non-null     float64
#  9   estadual_rural   99 non-null     int64
#  10  municipal_rural  96 non-null     float64
#  11  privada_rural    96 non-null     float64
#  12  total_fund       99 non-null     int64
#  13  anos_iniciais    99 non-null     int64
#  14  anos_finais      99 non-null     int64
#  15  total_medio      99 non-null     int64
#  16  total_fem        99 non-null     int64
#  17  nao_dec_fem      99 non-null     int64
#  18  branca_fem       99 non-null     int64
#  19  preta_fem        99 non-null     int64
#  20  parda_fem        99 non-null     int64
#  21  amarela_fem      99 non-null     int64
#  22  indígena_fem     99 non-null     int64
#  23  total_masc       99 non-null     int64
#  24  nao_dec_masc     99 non-null     int64
#  25  branca_masc      99 non-null     int64
#  26  preta_masc       99 non-null     int64
#  27  parda_masc       99 non-null     int64
#  28  amarela_masc     99 non-null     int64
#  29  indígena_masc    99 non-null     int64
#  30  6_10_anos        99 non-null     int64
#  31  11_14_anos       99 non-null     int64
#  32  15_17_anos       99 non-null     int64
# dtypes: float64(4), int64(28), object(1)
# memory usage: 25.6+ KB

# %%
# Definição do schema de validação no PySpark
from pyspark.sql.types import *
from pyspark.sql.types import StructType,StructField,StringType,IntegerType,DoubleType # importando estrutura da tabela (structType)
schema = StructType([StructField('ano',IntegerType(),True),
                     StructField('und_geografica',StringType(),True),
                     StructField('total_fem',IntegerType(),True),
                     StructField('nao_dec_fem',IntegerType(),True),
                     StructField('branca_fem',IntegerType(),True),
                     StructField('preta_fem',IntegerType(),True),
                     StructField('parda_fem',IntegerType(),True),
                     StructField('amarela_fem',IntegerType(),True),
                     StructField('indígena_fem',IntegerType(),True),
                     StructField('total_masc',IntegerType(),True),
                     StructField('nao_dec_masc',IntegerType(),True),
                     StructField('branca_masc',IntegerType(),True),
                     StructField('preta_masc',IntegerType(),True),
                     StructField('parda_masc',IntegerType(),True),
                     StructField('amarela_masc',IntegerType(),True),
                     StructField('indígena_masc',IntegerType(),True),
                     StructField('total_urb',IntegerType(),True),
                     StructField('federal_urb',IntegerType(),True),
                     StructField('estadual_urb',IntegerType(),True),
                     StructField('municipal_urb',IntegerType(),True),
                     StructField('privada_urb',IntegerType(),True),
                     StructField('total_rural',IntegerType(),True),
                     StructField('federal_rural',IntegerType(),True),
                     StructField('estadual_rural',IntegerType(),True),
                     StructField('municipal_rural',IntegerType(),True),
                     StructField('privada_rural',IntegerType(),True),
                     StructField('total_fund',IntegerType(),True),
                     StructField('anos_iniciais',IntegerType(),True),
                     StructField('anos_finais',IntegerType(),True),
                     StructField('total_medio',IntegerType(),True),
                     StructField('total_fem',IntegerType(),True),
                     StructField('6_10_anos',IntegerType(),True),
                     StructField('11_14_anos',IntegerType(),True),
                     StructField('15_17_anos',IntegerType(),True),
])
# Visualização do df no PySpark
df_py.show()
# Out:
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# | ano|     und_geografica|total_urb|federal_urb|estadual_urb|municipal_urb|privada_urb|total_rural|federal_rural|estadual_rural|municipal_rural|privada_rural|total_fund|anos_iniciais|anos_finais|total_medio|total_fem|nao_dec_fem|branca_fem|preta_fem|parda_fem|amarela_fem|indígena_fem|total_masc|nao_dec_masc|branca_masc|preta_masc|parda_masc|amarela_masc|indígena_masc|6_10_anos|11_14_anos|15_17_anos|
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# |2018|             Brasil| 42982279|     355937|    15116036|  1.8603701E7|    8906605|    5473588|      55141.0|         83038|      4499423.0|      88644.0|  27183970|     15176420|   12007550|    7709929| 23823004|    6702314|   7645543|   799424|  8441075|      81019|      153629|  24632863|     6961968|    7734773|    866697|   8826429|       82927|       160069| 13976552|  11758610|   8281372|
# |2018|              Norte|  3820251|      44265|     1558439|    1765537.0|     452010|    1172239|       3751.0|        209812|       951067.0|       7609.0|   3051017|      1756349|    1294668|     783745|  2447362|     764862|    255087|     4094|  1310064|       6556|       69853|   2545128|      807269|     244596|     48123|   1364518|        6584|        74038|  1519511|   1270916|    853540|
# |2018|           Rondônia|   364763|       7134|      183229|     132891.0|      41509|      64166|       1208.0|         13301|        46970.0|       2687.0|    269626|       154275|     115351|      59573|   210287|      51547|     47716|     4586|   102649|       1152|        2637|    218642|       54558|      46351|      5557|    108208|        1166|         2802|   128739|    108702|     77922|
# |2018|               Acre|   202003|       2776|      123599|      63209.0|      12419|      82058|          NaN|         46214|        35844.0|          NaN|    157646|        92305|      65341|      38141|   139433|      51045|     12334|     1418|    69144|       5000|        4992|    144628|       52037|      11888|      1797|     73174|        5400|         5192|    79739|     66137|     46071|
# |2018|           Amazonas|   905025|      10969|      412804|     394460.0|      86792|     260329|        551.0|         48459|       210766.0|        553.0|    705007|       405108|     299899|     205698|   577874|      85432|     49753|     5206|   399077|       8960|        3751|    587480|       86732|      47043|      5766|    407493|        8440|        39602|   361936|    298930|    202325|
# |2018|            Roraima|   118350|       2073|       51196|      49643.0|      15438|      38505|        655.0|         22112|        15714.0|         24.0|     96582|        53790|      42792|      22191|    76988|      19784|      7670|     1027|    38117|       1310|       10259|     79867|       20553|       7331|      1058|     39922|        1330|         1087|    52034|     39811|     25985|
# |2018|               Pará|  1687179|      13578|      545962|     896649.0|     230990|     641260|        462.0|         38987|       598819.0|       2992.0|   1439788|       833802|     605986|     359331|  1135941|     495275|     89729|    19087|   521218|       2373|        8259|   1192498|      527768|      85559|     22539|    545138|        2303|         9191|   705604|    597004|    390724|
# |2018|              Amapá|   185820|       3358|       98279|      61377.0|      22806|      40351|          NaN|         26136|        13855.0|        360.0|    136185|        81103|      55082|      35427|   111049|      28055|     13521|       28|    63744|       2340|        2695|    115122|       29575|      12456|      3336|     66626|        2700|         2859|    70420|     57504|     42249|
# |2018|          Tocantins|   357111|       4377|      143370|     167308.0|      42056|      45570|        875.0|         14603|        29099.0|        993.0|    246183|       135966|     110217|      63384|   195790|      33724|     34364|     6816|   116115|        127|        3501|    206891|       36046|      33968|       807|    123957|        1328|         3522|   121039|    102828|     68264|
# |2018|           Nordeste| 11207641|     115088|     3084696|    5580475.0|    2427382|    3005801|      17633.0|        231935|      2711659.0|      44574.0|   8039593|      4477690|    3561903|    2183818|  6986328|    2247480|    944810|   250061|  3481244|      26682|       36051|   7227114|     2338323|     921938|    273946|   3629144|       25971|        37792|  4017806|   3447895|   2421252|
# |2018|           Maranhão|  1336316|       1234|      286364|     827158.0|     210454|     694796|       3504.0|         59741|       610010.0|      21541.0|   1178949|       659333|     519616|     311830|   992593|     317796|     89617|    20176|   552645|       2687|        9672|   1038519|      335753|      86360|     22682|    580711|         282|        10193|   593716|    503020|    324164|
# |2018|              Piauí|   767519|      11021|      289846|     355018.0|     111634|     199406|        687.0|         12406|       186060.0|        253.0|    480126|       272639|     207487|     135125|   473466|     110110|     57189|    17458|   283987|       4181|        5410|    493459|      117611|      54042|      1996|    297286|        4022|         5380|   241348|    208320|    159082|
# |2018|              Ceará|  1788313|      10831|      399529|     959304.0|     418649|     387351|        547.0|         23727|       362036.0|       1041.0|   1198116|       659500|     538616|     367781|  1070391|     260342|    160194|    11586|   631239|       2996|        4034|   1105273|      268252|     155061|     13322|    661644|         282|         4174|   630766|    525890|    369972|
# |2018|Rio Grande do Norte|   706369|      20117|      212148|     304899.0|     169205|     123094|       4811.0|          8242|       108732.0|       1309.0|    467629|       259295|     208334|     124592|   405941|     153416|     98797|     6472|   145280|       1248|        7280|    423522|      162053|      97390|      7423|    154765|        1091|         8000|   233578|    198558|    141940|
# |2018|            Paraíba|   832628|       9919|      257407|     376349.0|     188953|     151593|        428.0|           169|       133568.0|        697.0|    556248|       308634|     247614|     141297|   482610|     134259|     96145|    10714|   236121|        244|        2931|    501611|      139313|      94101|      1204|    250768|        2357|         3032|   276778|    235605|    163238|
# |2018|         Pernambuco|  1889499|      14552|      531940|     829079.0|     513928|     362453|       3446.0|         52005|       299749.0|       7253.0|   1301930|       737135|     564795|     339909|  1109309|     418768|    202675|    26303|   449707|       3463|        8393|   1142643|      428828|     199469|     29413|    472495|         339|         9048|   656269|    561705|    391298|
# |2018|            Alagoas|   671847|      11492|      167542|     349138.0|     143675|     198732|          NaN|         11028|       186320.0|       1384.0|    490587|       272869|     217718|     118393|   431275|     126428|     57754|      913|   234408|       1366|        2189|    439304|      129258|      55260|     10541|    240701|        1292|         2252|   244255|    209192|    145424|
# |2018|            Sergipe|   433430|       3767|      146261|     163702.0|     119700|     110963|       1330.0|          6609|       101380.0|       1644.0|    331297|       185177|     146120|      77939|   267662|      81992|     30485|     7801|   145747|       1233|        4040|    276731|       84861|      29851|      8466|    151937|        1215|         4010|   159077|    139359|     96291|
# |2018|              Bahia|  2781720|      21049|      793659|    1415828.0|     551184|     777413|       2880.0|         41277|       723804.0|       9452.0|   2034711|      1123108|     911603|     566952|  1753081|     644369|    151954|   140421|   802110|       7068|        7159|   1806052|      672394|     150404|    150099|    818837|        6964|         7354|   982019|    866246|    629843|
# |2018|            Sudeste| 18415002|     106536|     6622676|    7458143.0|    4227647|     659938|      19763.0|        159872|       453185.0|      27118.0|  10384471|      5814430|    4570041|    3151377|  9398720|    2255191|   4015852|   398327|  2686185|      31245|        1192|   9676220|     2307308|    4089831|    426504|   2807819|       32803|        11955|  5479283|   4561962|   3284899|
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# # **Carregamento**

# %%
# Exportação em uma pasta Google Drive
# df.to_csv('/content/drive/MyDrive/Projeto_final/tratado/matriculas_total_tratado.csv',index=False)

# %% [markdown]
# ## **Google Cloud Platform**

# %%
# Carregamento na pasta tratada no Google Cloud Platform
df.to_csv('gs://educacao13/projeto_educacao/tratado/matriculas_total_tratado.csv', index=False)

# %% [markdown]
# ## MongoDB

# %%
# Carregamento no MongoDB
db2 = client['pandasmongo']
collection2 = db2['matriculas_tratado']
collection2.count_documents({})
# Out:
# 198

# %%
# Conversão de dados para MongoDB
df_dict = df.to_dict("records")
collection2.insert_many(df_dict)

# %%
# Contagem de dados: verificação
collection2.count_documents({})
# Out:
# 198

# %%
# Checagem da coleção
for x in collection2.find():
   print(x)

# %% [markdown]
# ## Backup 3

# %%
# Terceiro Backup
df_back3 = df.copy()

# %% [markdown]
# ## **Análise**

# %%
# Formatação/padronização do describe
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# Correlação de todos os dados da tabela
df_1.describe()
# Out:
#        Curso_Técnico_Integrado  Associada ao Ensino Médio12  \
# count                 99.00000                     99.00000
# mean                  56.86300                     66.14742
# std                  117.68590                    135.49056
# min                    1.29100                      1.30900
# 25%                    6.92550                      7.68600
# 50%                   20.97700                     24.72500
# 75%                   40.30550                     54.13750
# max                  750.12500                    834.54600
#
#        Curso Técnico Concomitante  Curso Técnico Subsequente
# count                    99.00000                   99.00000
# mean                     73.32655                   94.04009
# std                     170.89380                  196.51249
# min                       1.03900                    2.12600
# 25%                       3.39800                    9.00750
# 50%                       8.74500                   23.05500
# 75%                      41.79200                   65.98600
# max                     913.00000                  973.00000

# %%
# Seleção das colunas do DF das colunas com matriculas de alunos do ensino fundamnetal
# anos iniciais e finais em relação ao sexo e cor
corr_ms = df_py.select('anos_iniciais', 'anos_finais', 'total_medio',
       'nao_dec_fem', 'branca_fem', 'preta_fem', 'parda_fem', 'amarela_fem',
       'indígena_fem', 'nao_dec_masc', 'branca_masc',
       'preta_masc', 'parda_masc', 'amarela_masc', 'indígena_masc')
corr_ms = corr_ms.toPandas()

# %%
# Correlação dos alunos matriculados por sexo
corr_ms.describe()
# Out:
#        anos_iniciais    anos_finais   total_medio   nao_dec_fem    branca_fem  \
# count       99.00000       99.00000      99.00000      99.00000      99.00000
# mean   1349086.81818  1085914.03030  700829.60606  592074.36364  688788.75758
# std    2694327.87431  2167494.30985 1408088.66584 1175638.00946 1485132.90664
# min      53790.00000    42792.00000   22191.00000   18726.00000    7670.00000
# 25%     242662.50000   202438.50000  117223.50000   84562.50000   54419.50000
# 50%     480246.00000   398644.00000  254670.00000  267386.00000  141779.00000
# 75%    1122690.50000   898772.50000  590849.00000  626355.50000  532137.50000
# max   15176420.00000 12007550.00000 7866695.00000 6702314.00000 7645543.00000
#
#          preta_fem     parda_fem  amarela_fem  indígena_fem  nao_dec_masc  \
# count     99.00000      99.00000     99.00000      99.00000      99.00000
# mean   67239.87879  762234.18182   7842.06061   11698.93939  610012.03030
# std   150744.23770 1534320.54187  14223.03251   20379.05744 1210065.04141
# min       28.00000   38117.00000    127.00000      52.00000   19328.00000
# 25%     5388.50000  118433.50000   1406.50000    3213.00000   87458.00000
# 50%    13009.00000  249473.00000   3548.00000    5259.00000  271567.00000
# 75%    40985.00000  602494.50000   7152.50000   10339.00000  639817.50000
# max   799424.00000 8441075.00000  81019.00000  153629.00000 6961968.00000
#
#         branca_masc   preta_masc    parda_masc  amarela_masc  indígena_masc
# count      99.00000     99.00000      99.00000      99.00000       99.00000
# mean   696508.00000  69206.84848  795795.96970    7993.24242    14751.03030
# std   1505681.56990 156909.49984 1600925.61274   14641.90003    31176.47393
# min      7331.00000    152.00000   39922.00000     101.00000      481.00000
# 25%     52439.50000   5166.00000  123407.00000    1318.50000     2818.50000
# 50%    137002.00000  13986.00000  257946.00000    3375.00000     4900.00000
# 75%    548461.50000  47102.50000  630888.50000    7068.00000    10163.50000
# max   7734773.00000 866697.00000 8826429.00000   82927.00000   179715.00000

# %%
# Visualização da correlação de Pearson com dados padronizados com o mapa de calor
correlation = corr_ms.corr(method='pearson')
mascara = np.triu(np.ones_like(correlation, dtype=bool))
plt.figure(figsize = ((10, 7)))
plot = sns.heatmap(correlation,
                   mask=mascara,
                   annot = True,
                   fmt=".1f", vmax=1, center=0, vmin=-1,
                   cbar=True, cmap='coolwarm',
                   linewidths=.5,
                   cbar_kws={"shrink": .5, 'label': 'Correlação', 'orientation': 'vertical'})

plt.title("Mapa de Calor: Correlação de Pearson (Matriculas por sexo e cor)")
plt.show()

# %%
# Seleção das colunas do DF
corr_zona = df_py.select('federal_urb', 'estadual_urb',
       'municipal_urb', 'privada_urb', 'federal_rural',
       'estadual_rural', 'municipal_rural', 'privada_rural', 'anos_iniciais', 'anos_finais',
        '6_10_anos', '11_14_anos', '15_17_anos')
corr_zona = corr_zona.toPandas()

# %%
# Correlação dos alunos matriculados por localização da escola (zona urbana e rural, etc...) e idade
corr_zona.describe()
# Out:
#        federal_urb   estadual_urb  municipal_urb   privada_urb  federal_rural  \
# count     99.00000       99.00000       96.00000      99.00000       90.00000
# mean   30412.54545  1316527.63636  1754082.81250  803526.15152     5179.16667
# std    62183.87985  2669921.96654  3458319.34120 1669253.37766     9837.81634
# min      252.00000    51196.00000    49643.00000   11461.00000      109.00000
# 25%     4464.50000   207084.00000   322596.75000  105213.50000      877.25000
# 50%    11671.00000   431234.00000   784536.00000  230990.00000     1643.50000
# 75%    22727.00000  1001724.00000  1467762.00000  546584.50000     4362.25000
# max   355937.00000 15116036.00000 18855595.00000 8907040.00000    55141.00000
#
#        estadual_rural  municipal_rural  privada_rural  anos_iniciais  \
# count        99.00000         96.00000       96.00000       99.00000
# mean      64959.63636     409722.28125     8441.18750  1349086.81818
# std      122083.37904     859940.11650    17524.47979  2694327.87431
# min         169.00000      13727.00000       14.00000    53790.00000
# 25%       11533.00000      55216.00000     1071.50000   242662.50000
# 50%       27548.00000     126891.00000     1946.00000   480246.00000
# 75%       54004.00000     310257.50000     7342.00000  1122690.50000
# max      820393.00000    4499423.00000    93006.00000 15176420.00000
#
#          anos_finais      6_10_anos     11_14_anos    15_17_anos
# count       99.00000       99.00000       99.00000      99.00000
# mean   1085914.03030  1272573.81818  1046012.03030  748918.21212
# std    2167494.30985  2545592.24073  2091477.68448 1502384.30774
# min      42792.00000    52034.00000    39811.00000   25985.00000
# 25%     202438.50000   226776.50000   190304.50000  137257.50000
# 50%     398644.00000   472972.00000   383228.00000  274014.00000
# 75%     898772.50000  1036188.50000   863266.50000  630720.00000
# max   12007550.00000 14111055.00000 11758610.00000 8304843.00000

# %%
# Visualização da correlação de Pearson com dados padronizados com mapa de calor
correlation = corr_zona.corr(method='pearson')
mascara = np.triu(np.ones_like(correlation, dtype=bool))
plt.figure(figsize = ((10, 7)))
plot = sns.heatmap(correlation,
                   mask=mascara,
                   annot = True,
                   fmt=".1f", vmax=1, center=0, vmin=-1,
                   cbar=True, cmap='coolwarm',
                   linewidths=.5,
                   cbar_kws={"shrink": .5, 'label': 'Correlação', 'orientation': 'vertical'})

plt.title("Mapa de Calor: Correlação de Pearson (Matriculas por localização e idade)")
plt.show()

# %% [markdown]
# ### Group by

# %%
#Exportação do dataframe do Pandas para o PySpark
df_py_2 = spark.createDataFrame(df)
# Out:
# /content/spark-3.1.1-bin-hadoop3.2/python/pyspark/sql/pandas/conversion.py:331: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# Visualização do df no PySpark
df_py_2.show()
# Out:
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# | ano|     und_geografica|total_urb|federal_urb|estadual_urb|municipal_urb|privada_urb|total_rural|federal_rural|estadual_rural|municipal_rural|privada_rural|total_fund|anos_iniciais|anos_finais|total_medio|total_fem|nao_dec_fem|branca_fem|preta_fem|parda_fem|amarela_fem|indígena_fem|total_masc|nao_dec_masc|branca_masc|preta_masc|parda_masc|amarela_masc|indígena_masc|6_10_anos|11_14_anos|15_17_anos|
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# |2018|             Brasil| 42982279|     355937|    15116036|  1.8603701E7|    8906605|    5473588|      55141.0|         83038|      4499423.0|      88644.0|  27183970|     15176420|   12007550|    7709929| 23823004|    6702314|   7645543|   799424|  8441075|      81019|      153629|  24632863|     6961968|    7734773|    866697|   8826429|       82927|       160069| 13976552|  11758610|   8281372|
# |2018|              Norte|  3820251|      44265|     1558439|    1765537.0|     452010|    1172239|       3751.0|        209812|       951067.0|       7609.0|   3051017|      1756349|    1294668|     783745|  2447362|     764862|    255087|     4094|  1310064|       6556|       69853|   2545128|      807269|     244596|     48123|   1364518|        6584|        74038|  1519511|   1270916|    853540|
# |2018|           Rondônia|   364763|       7134|      183229|     132891.0|      41509|      64166|       1208.0|         13301|        46970.0|       2687.0|    269626|       154275|     115351|      59573|   210287|      51547|     47716|     4586|   102649|       1152|        2637|    218642|       54558|      46351|      5557|    108208|        1166|         2802|   128739|    108702|     77922|
# |2018|               Acre|   202003|       2776|      123599|      63209.0|      12419|      82058|          NaN|         46214|        35844.0|          NaN|    157646|        92305|      65341|      38141|   139433|      51045|     12334|     1418|    69144|       5000|        4992|    144628|       52037|      11888|      1797|     73174|        5400|         5192|    79739|     66137|     46071|
# |2018|           Amazonas|   905025|      10969|      412804|     394460.0|      86792|     260329|        551.0|         48459|       210766.0|        553.0|    705007|       405108|     299899|     205698|   577874|      85432|     49753|     5206|   399077|       8960|        3751|    587480|       86732|      47043|      5766|    407493|        8440|        39602|   361936|    298930|    202325|
# |2018|            Roraima|   118350|       2073|       51196|      49643.0|      15438|      38505|        655.0|         22112|        15714.0|         24.0|     96582|        53790|      42792|      22191|    76988|      19784|      7670|     1027|    38117|       1310|       10259|     79867|       20553|       7331|      1058|     39922|        1330|         1087|    52034|     39811|     25985|
# |2018|               Pará|  1687179|      13578|      545962|     896649.0|     230990|     641260|        462.0|         38987|       598819.0|       2992.0|   1439788|       833802|     605986|     359331|  1135941|     495275|     89729|    19087|   521218|       2373|        8259|   1192498|      527768|      85559|     22539|    545138|        2303|         9191|   705604|    597004|    390724|
# |2018|              Amapá|   185820|       3358|       98279|      61377.0|      22806|      40351|          NaN|         26136|        13855.0|        360.0|    136185|        81103|      55082|      35427|   111049|      28055|     13521|       28|    63744|       2340|        2695|    115122|       29575|      12456|      3336|     66626|        2700|         2859|    70420|     57504|     42249|
# |2018|          Tocantins|   357111|       4377|      143370|     167308.0|      42056|      45570|        875.0|         14603|        29099.0|        993.0|    246183|       135966|     110217|      63384|   195790|      33724|     34364|     6816|   116115|        127|        3501|    206891|       36046|      33968|       807|    123957|        1328|         3522|   121039|    102828|     68264|
# |2018|           Nordeste| 11207641|     115088|     3084696|    5580475.0|    2427382|    3005801|      17633.0|        231935|      2711659.0|      44574.0|   8039593|      4477690|    3561903|    2183818|  6986328|    2247480|    944810|   250061|  3481244|      26682|       36051|   7227114|     2338323|     921938|    273946|   3629144|       25971|        37792|  4017806|   3447895|   2421252|
# |2018|           Maranhão|  1336316|       1234|      286364|     827158.0|     210454|     694796|       3504.0|         59741|       610010.0|      21541.0|   1178949|       659333|     519616|     311830|   992593|     317796|     89617|    20176|   552645|       2687|        9672|   1038519|      335753|      86360|     22682|    580711|         282|        10193|   593716|    503020|    324164|
# |2018|              Piauí|   767519|      11021|      289846|     355018.0|     111634|     199406|        687.0|         12406|       186060.0|        253.0|    480126|       272639|     207487|     135125|   473466|     110110|     57189|    17458|   283987|       4181|        5410|    493459|      117611|      54042|      1996|    297286|        4022|         5380|   241348|    208320|    159082|
# |2018|              Ceará|  1788313|      10831|      399529|     959304.0|     418649|     387351|        547.0|         23727|       362036.0|       1041.0|   1198116|       659500|     538616|     367781|  1070391|     260342|    160194|    11586|   631239|       2996|        4034|   1105273|      268252|     155061|     13322|    661644|         282|         4174|   630766|    525890|    369972|
# |2018|Rio Grande do Norte|   706369|      20117|      212148|     304899.0|     169205|     123094|       4811.0|          8242|       108732.0|       1309.0|    467629|       259295|     208334|     124592|   405941|     153416|     98797|     6472|   145280|       1248|        7280|    423522|      162053|      97390|      7423|    154765|        1091|         8000|   233578|    198558|    141940|
# |2018|            Paraíba|   832628|       9919|      257407|     376349.0|     188953|     151593|        428.0|           169|       133568.0|        697.0|    556248|       308634|     247614|     141297|   482610|     134259|     96145|    10714|   236121|        244|        2931|    501611|      139313|      94101|      1204|    250768|        2357|         3032|   276778|    235605|    163238|
# |2018|         Pernambuco|  1889499|      14552|      531940|     829079.0|     513928|     362453|       3446.0|         52005|       299749.0|       7253.0|   1301930|       737135|     564795|     339909|  1109309|     418768|    202675|    26303|   449707|       3463|        8393|   1142643|      428828|     199469|     29413|    472495|         339|         9048|   656269|    561705|    391298|
# |2018|            Alagoas|   671847|      11492|      167542|     349138.0|     143675|     198732|          NaN|         11028|       186320.0|       1384.0|    490587|       272869|     217718|     118393|   431275|     126428|     57754|      913|   234408|       1366|        2189|    439304|      129258|      55260|     10541|    240701|        1292|         2252|   244255|    209192|    145424|
# |2018|            Sergipe|   433430|       3767|      146261|     163702.0|     119700|     110963|       1330.0|          6609|       101380.0|       1644.0|    331297|       185177|     146120|      77939|   267662|      81992|     30485|     7801|   145747|       1233|        4040|    276731|       84861|      29851|      8466|    151937|        1215|         4010|   159077|    139359|     96291|
# |2018|              Bahia|  2781720|      21049|      793659|    1415828.0|     551184|     777413|       2880.0|         41277|       723804.0|       9452.0|   2034711|      1123108|     911603|     566952|  1753081|     644369|    151954|   140421|   802110|       7068|        7159|   1806052|      672394|     150404|    150099|    818837|        6964|         7354|   982019|    866246|    629843|
# |2018|            Sudeste| 18415002|     106536|     6622676|    7458143.0|    4227647|     659938|      19763.0|        159872|       453185.0|      27118.0|  10384471|      5814430|    4570041|    3151377|  9398720|    2255191|   4015852|   398327|  2686185|      31245|        1192|   9676220|     2307308|    4089831|    426504|   2807819|       32803|        11955|  5479283|   4561962|   3284899|
# +----+-------------------+---------+-----------+------------+-------------+-----------+-----------+-------------+--------------+---------------+-------------+----------+-------------+-----------+-----------+---------+-----------+----------+---------+---------+-----------+------------+----------+------------+-----------+----------+----------+------------+-------------+---------+----------+----------+
# only showing top 20 rows

# %%
# Agrupamento do DataFrame e cálculo do valor máximo da coluna para o grupo de idade.
group_1 = df_py_2.groupBy('ano','und_geografica').agg({'6_10_anos': 'max'})
group_1.show()
# Out:
# +----+--------------+--------------+
# | ano|und_geografica|max(6_10_anos)|
# +----+--------------+--------------+
# |2018|       Sudeste|       5479283|
# |2020|   Mato Grosso|        263153|
# |2020|      Nordeste|       3880056|
# |2022|       Alagoas|        232875|
# |2020|         Amapá|         69367|
# |2020|          Acre|         78951|
# |2018|          Pará|        705604|
# |2018|      Amazonas|        361936|
# |2018|  Minas Gerais|       1288508|
# |2018|Santa Catarina|        448721|
# |2022|       Paraíba|        273541|
# |2018|         Norte|       1519511|
# |2022|Santa Catarina|        508063|
# |2020|       Paraíba|        268925|
# |2022|        Brasil|      14111055|
# |2020|       Sergipe|        154848|
# |2018|       Roraima|         52034|
# |2018|       Sergipe|        159077|
# |2018|          Acre|         79739|
# |2018|  Centro-Oeste|       1110293|
# +----+--------------+--------------+
# only showing top 20 rows

# %%
# Agrupamento do DataFrame e cálculo do valor máximo da coluna para o grupo de idade.
group_2 = df_py_2.groupBy('ano','und_geografica').agg({'11_14_anos': 'max'})
group_2.show()
# Out:
# +----+--------------+---------------+
# | ano|und_geografica|max(11_14_anos)|
# +----+--------------+---------------+
# |2018|       Sudeste|        4561962|
# |2020|   Mato Grosso|         208256|
# |2020|      Nordeste|        3368108|
# |2022|       Alagoas|         196377|
# |2020|         Amapá|          57012|
# |2020|          Acre|          65754|
# |2018|          Pará|         597004|
# |2018|      Amazonas|         298930|
# |2018|  Minas Gerais|        1098848|
# |2018|Santa Catarina|         372368|
# |2022|       Paraíba|         228438|
# |2018|         Norte|        1270916|
# |2022|Santa Catarina|         387974|
# |2020|       Paraíba|         233160|
# |2022|        Brasil|       11264137|
# |2020|       Sergipe|         138110|
# |2018|       Roraima|          39811|
# |2018|       Sergipe|         139359|
# |2018|          Acre|          66137|
# |2018|  Centro-Oeste|         924922|
# +----+--------------+---------------+
# only showing top 20 rows

# %%
# Agrupamento do DataFrame e cálculo do valor máximo da coluna para o grupo de idade.
group_3 = df_py_2.groupBy('ano','und_geografica').agg({'15_17_anos': 'max'})
group_3.show()
# Out:
# +----+--------------+---------------+
# | ano|und_geografica|max(15_17_anos)|
# +----+--------------+---------------+
# |2018|       Sudeste|        3284899|
# |2020|   Mato Grosso|         139474|
# |2020|      Nordeste|        2355447|
# |2022|       Alagoas|         138303|
# |2020|         Amapá|          38005|
# |2020|          Acre|          44316|
# |2018|          Pará|         390724|
# |2018|      Amazonas|         202325|
# |2018|  Minas Gerais|         843649|
# |2018|Santa Catarina|         267087|
# |2022|       Paraíba|         156007|
# |2018|         Norte|         853540|
# |2022|Santa Catarina|         285355|
# |2020|       Paraíba|         159585|
# |2022|        Brasil|        8304843|
# |2020|       Sergipe|          93284|
# |2018|       Roraima|          25985|
# |2018|       Sergipe|          96291|
# |2018|          Acre|          46071|
# |2018|  Centro-Oeste|         631597|
# +----+--------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### **Resumo de Estatística**

# %%
# describe geral
describe_df = df_py_2.describe()
describe_df.show()
# Out:
# +-------+------------------+--------------+------------------+------------------+------------------+-------------+------------------+------------------+-------------+------------------+---------------+-------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |summary|               ano|und_geografica|         total_urb|       federal_urb|      estadual_urb|municipal_urb|       privada_urb|       total_rural|federal_rural|    estadual_rural|municipal_rural|privada_rural|        total_fund|     anos_iniciais|       anos_finais|       total_medio|         total_fem|       nao_dec_fem|        branca_fem|         preta_fem|         parda_fem|       amarela_fem|      indígena_fem|        total_masc|      nao_dec_masc|      branca_masc|        preta_masc|        parda_masc|      amarela_masc|     indígena_masc|         6_10_anos|        11_14_anos|        15_17_anos|
# +-------+------------------+--------------+------------------+------------------+------------------+-------------+------------------+------------------+-------------+------------------+---------------+-------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |  count|                99|            99|                99|                99|                99|           99|                99|                99|           99|                99|             99|           99|                99|                99|                99|                99|                99|                99|                99|                99|                99|                99|                99|                99|                99|               99|                99|                99|                99|                99|                99|                99|                99|
# |   mean|            2020.0|          null|3852567.5757575757|30412.545454545456|1316527.6363636365|          NaN| 803526.1515151515| 484803.1818181818|          NaN| 64959.63636363636|            NaN|          NaN|2435000.8484848486|1349086.8181818181|1085914.0303030303| 700829.6060606061|2136437.8181818184| 592074.3636363636| 688788.7575757576| 67239.87878787878| 762234.1818181818| 7842.060606060606|11698.939393939394|2200932.9393939395| 610012.0303030303|         696508.0| 69206.84848484848| 795795.9696969697| 7993.242424242424|14751.030303030304|1272573.8181818181|1046012.0303030303| 748918.2121212122|
# | stddev|1.6413036132967775|          null| 7794602.697319923|62183.879846309515|2669921.9665381815|          NaN|1669253.3776563248|1009677.4832482184|          NaN|122083.37903774853|            NaN|          NaN| 4861522.993112796| 2694327.874314367|2167494.3098460557|1408088.6658441473| 4283625.153786945|1175638.0094643135|1485132.9066366905|150744.23769731412|1534320.5418709314|14223.032512563284|20379.057439409175| 4410945.540698406|1210065.0414063046|1505681.569903965|156909.49984224062|1600925.6127412955|14641.900032197858| 31176.47393450498|2545592.2407319527|2091477.6844808937|1502384.3077435163|
# |    min|              2018|          Acre|            118350|               252|             51196|      49643.0|             11461|             24737|        109.0|               169|        13727.0|         14.0|             96582|             53790|             42792|             22191|             76988|             18726|              7670|                28|             38117|               127|                52|             79867|             19328|             7331|               152|             39922|               101|               481|             52034|             39811|             25985|
# |    max|              2022|     Tocantins|          42982279|            355937|          15116036|          NaN|           8907040|           5473588|          NaN|            820393|            NaN|          NaN|          27183970|          15176420|          12007550|           7866695|          23823004|           6702314|           7645543|            799424|           8441075|             81019|            153629|          24632863|           6961968|          7734773|            866697|           8826429|             82927|            179715|          14111055|          11758610|           8304843|
# +-------+------------------+--------------+------------------+------------------+------------------+-------------+------------------+------------------+-------------+------------------+---------------+-------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+

# %%
# describe com enfase nos valores totais para obter os valores minimos e maximos  de cada parametro
describe_df = df_py_2.describe(['total_fund', 'total_medio', 'total_rural', 'total_urb', 'total_fem', '15_17_anos'])
describe_df.show()
# Out:
# +-------+------------------+------------------+------------------+------------------+------------------+------------------+
# |summary|        total_fund|       total_medio|       total_rural|         total_urb|         total_fem|        15_17_anos|
# +-------+------------------+------------------+------------------+------------------+------------------+------------------+
# |  count|                99|                99|                99|                99|                99|                99|
# |   mean|2435000.8484848486| 700829.6060606061| 484803.1818181818|3852567.5757575757|2136437.8181818184| 748918.2121212122|
# | stddev| 4861522.993112796|1408088.6658441473|1009677.4832482184| 7794602.697319923| 4283625.153786945|1502384.3077435163|
# |    min|             96582|             22191|             24737|            118350|             76988|             25985|
# |    max|          27183970|           7866695|           5473588|          42982279|          23823004|           8304843|
# +-------+------------------+------------------+------------------+------------------+------------------+------------------+
